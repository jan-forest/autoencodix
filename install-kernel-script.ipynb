# %% [markdown]
# # Kernel Installation

# %% [markdown]
# ## Run the following line (script) once to initialize the kernel as well as allocate a workspace and link it to your home directory. More on this [here](https://doc.zih.tu-dresden.de/quickstart/getting_started/#allocate-a-workspace)

# %%
! ./install-kernel.sh

# %% [markdown]
# ## If you are seeing "Success!" Your next steps are:
#
# 1. Re-load the browser
# 2. Relocate to `Tutorials` in directory `/horse/$USER-AE-ws/autoencodix/Tutorials`
# 3. Open `Quick_Start.ipynb` notebook
# 4. If not already pre-selected: Select the `autoencodix-ga-kernel`: Top Menu -> Kernel -> Change Kernel

# %% [markdown]
# If you are running into any issues, see the [troubleshooting section](https://github.com/jan-forest/autoencodix/tree/ga-workshop?tab=readme-ov-file#troubleshooting) of the `README.md` to debug. Then run the above cell again.
