# %% [markdown]
# # Kernel Installation

# %% [markdown]
# ## Run the following line (script) once to initialize the kernel as well as allocate a workspace and link it to your home directory. More on this [here](https://doc.zih.tu-dresden.de/quickstart/getting_started/#allocate-a-workspace)

# %%
! ./install-kernel.sh
# Out:
# ...
#  Setting Modules
# ...
# The following modules were not unloaded:
#   (Use "module --force purge" to unload all):
#
#   1) release/24.04
# Modules SQLite/3.42.0, OpenSSL/1.1, GCCcore/12.3.0 and 4 dependencies unloaded.
# Modules GCCcore/11.3.0, Python/3.10.4 and 11 dependencies loaded.
# ...
#  Setting Kernel
# ...
# Activating virtual environment: /data/horse/ws/neju219d-AUTOENCODIX/autoencodix/venv-AUTOENCODIX-capella-no-ssp
# Installing kernel
# Installed kernelspec autoencodix-ga-kernel in /home/h6/majo158f/.local/share/jupyter/kernels/autoencodix-ga-kernel
# Creating kernel initialization script.
# Creating kernel intialization script.
# Replacing contents of /home/majo158f/.local/share/jupyter/kernels/autoencodix-ga-kernel/kernel.json
# Kernel installation complete.
# ...
#  Resetting modules & env, creating & registering  workspace
# ...
# Running "module reset". Resetting modules to system default. The following $MODULEPATH directories have been removed: None
# ...

# %% [markdown]
# If you are using Mac and running into a bug when creating a workspace, see [here](https://doc.zih.tu-dresden.de/data_lifecycle/workspaces/?h=workspace#faq-and-troubleshooting) to troubleshoot it. Then run the above cell again.
